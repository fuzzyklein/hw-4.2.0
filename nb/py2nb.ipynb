# %% [markdown]
# # `py2nb`

# %% [markdown]
# Convert a Python source file to a Jupyter Notebook.

# %%
from enum import IntEnum

# %%
class CellType(IntEnum):
    CODE = 0
    MARKDOWN = 1
    RAW = 2

# %% [markdown]
# Use a regular expression to identify docstrs, etc.

# %%
import re

# %%
help (re.compile)
# Out:
# Help on function compile in module re:
#
# compile(pattern, flags=0)
#     Compile a regular expression pattern, returning a Pattern object.

# %%
DOCSTR_REGEX = re.compile(r'"""')

# %%
import site

# %%
site.USER_SITE
# Out:
# '/home/fuzzy/.local/lib/python3.8/site-packages'

# %%
import os

# %%
sorted(os.listdir(site.USER_SITE))
# Out:
# ['IPython',
#  'Jinja2-3.0.1.dist-info',
#  'MarkupSafe-2.0.1.dist-info',
#  'Send2Trash-1.7.1.dist-info',
#  '__pycache__',
#  '_pyrsistent_version.py',
#  'anyio',
#  'anyio-3.2.1.dist-info',
#  'argon2',
#  'argon2_cffi-20.1.0.dist-info',
#  'async_generator',
#  'async_generator-1.10.dist-info',
#  'attr',
#  'attrs-21.2.0.dist-info',
#  'backcall',
#  'backcall-0.2.0.dist-info',
#  'bash',
#  'bash-0.6.dist-info',
#  'bleach',
#  'bleach-3.3.0.dist-info',
#  'debugpy',
#  'debugpy-1.3.0.dist-info',
#  'decorator-5.0.9.dist-info',
#  'decorator.py',
#  'defusedxml',
#  'defusedxml-0.7.1.dist-info',
#  'file',
#  'file-0.3.0.dist-info',
#  'ipykernel',
#  'ipykernel-6.0.1.dist-info',
#  'ipykernel_launcher.py',
#  'ipython-7.25.0.dist-info',
#  'ipython_genutils',
#  'ipython_genutils-0.2.0.dist-info',
#  'ipywidgets',
#  'ipywidgets-7.6.3.dist-info',
#  'jedi',
#  'jedi-0.18.0.dist-info',
#  'jinja2',
#  'json5',
#  'json5-0.9.6.dist-info',
#  'jsonschema',
# ...

# %%
import sys

# %%
sys.path
# Out:
# ['/home/fuzzy/Projects/develop-4.2.0/hw-4.2.0/nb',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/fuzzy/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/home/fuzzy/.local/lib/python3.8/site-packages/IPython/extensions',
#  '/home/fuzzy/.ipython',
#  '/home/fuzzy/Projects/develop-4.2.0/hw-4.2.0/nb/py2nb',
#  '/home/fuzzy/Projects/develop-4.2.0/hw-4.2.0/py2nb']

# %%
from pathlib import Path

# %%
os.chdir('../../py2nb/nb')

# %%
site.addsitedir(str(Path('../') / 'py2nb'))

# %%
from tools import *

# %%
import inspect

# %%
inspect.getfile(Path)
# Out:
# '/usr/lib/python3.8/pathlib.py'

# %%
source = inspect.getfile(re)
sample = Path(inspect.getfile(Path)).read_text()

# %%
print(sample)
# Out:
# import fnmatch
# import functools
# import io
# import ntpath
# import os
# import posixpath
# import re
# import sys
# from _collections_abc import Sequence
# from errno import EINVAL, ENOENT, ENOTDIR, EBADF, ELOOP
# from operator import attrgetter
# from stat import S_ISDIR, S_ISLNK, S_ISREG, S_ISSOCK, S_ISBLK, S_ISCHR, S_ISFIFO
# from urllib.parse import quote_from_bytes as urlquote_from_bytes
#
#
# supports_symlinks = True
# if os.name == 'nt':
#     import nt
#     if sys.getwindowsversion()[:2] >= (6, 0):
#         from nt import _getfinalpathname
#     else:
#         supports_symlinks = False
#         _getfinalpathname = None
# else:
#     nt = None
#
#
# __all__ = [
#     "PurePath", "PurePosixPath", "PureWindowsPath",
#     "Path", "PosixPath", "WindowsPath",
#     ]
#
# #
# # Internals
# #
#
# # EBADF - guard against macOS `stat` throwing EBADF
# _IGNORED_ERROS = (ENOENT, ENOTDIR, EBADF, ELOOP)
#
# _IGNORED_WINERRORS = (
# ...

# %%
help(re.Pattern.match)
# Out:
# Help on method_descriptor:
#
# match(self, /, string, pos=0, endpos=9223372036854775807)
#     Matches zero or more characters at the beginning of the string.

# %%
m = DOCSTR_REGEX.match(sample)

# %%
print(m)
# Out:
# None

# %%
public(re)
# Out:
# A           L          RegexFlag  UNICODE  error      match        sub
# ASCII       LOCALE     S          VERBOSE  escape     purge        subn
# DEBUG       M          Scanner    X        findall    search       template
# DOTALL      MULTILINE  T          compile  finditer   split
# I           Match      TEMPLATE   copyreg  fullmatch  sre_compile
# IGNORECASE  Pattern    U          enum     functools  sre_parse

# %%
print(inspect.getdoc(re))
# Out:
# Support for regular expressions (RE).
#
# This module provides regular expression matching operations similar to
# those found in Perl.  It supports both 8-bit and Unicode strings; both
# the pattern and the strings being processed can contain null bytes and
# characters outside the US ASCII range.
#
# Regular expressions can contain both special and ordinary characters.
# Most ordinary characters, like "A", "a", or "0", are the simplest
# regular expressions; they simply match themselves.  You can
# concatenate ordinary characters, so last matches the string 'last'.
#
# The special characters are:
#     "."      Matches any character except a newline.
#     "^"      Matches the start of the string.
#     "$"      Matches the end of the string or just before the newline at
#              the end of the string.
#     "*"      Matches 0 or more (greedy) repetitions of the preceding RE.
#              Greedy means that it will match as many repetitions as possible.
# ...

# %%
import tokenize

# %%
from io import StringIO

# %%
s = StringIO()

# %%
print('''"""Hello, World!

Print the usual greeting.
"""
print("hello, world!")
''', file=s)
s

# %%
tokens = tokenize.generate_tokens(s.readline)

# %%
tokens
# Out:
# <generator object _tokenize at 0x7f46302d3740>

# %%
for t in tokens:
    print(t)
# Out:
# TokenInfo(type=0 (ENDMARKER), string='', start=(1, 0), end=(1, 0), line='')
